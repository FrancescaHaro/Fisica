# %% [markdown]
# # 1. Onda sinusoidal en una cuerda

# %% [markdown]
# #### a)Parámetros de la función de onda

# %%
import random
n_onda = random.uniform(5.00, 10.01)
frecuencia_angular = random.uniform(2.00,8.01)
angulo_fase = random.uniform(0.00,3.15)
amplitud = random.uniform(0.50,1.01)

print("Número de onda: ", n_onda)
print("Frecuencia angular: ", frecuencia_angular)
print("Ángulo de fase: ", angulo_fase)
print("Amplitud: ", amplitud)
# Out:
# Número de onda:  8.263325328989186
# Frecuencia angular:  7.890741667230704
# Ángulo de fase:  1.6518799109472728
# Amplitud:  0.553950685947718

# %% [markdown]
# #### b)Gráfico y vs x en t=0,00s

# %%
import math
import matplotlib.pyplot as plt

def ecua(x,t):
    return amplitud*math.sin(n_onda*x+frecuencia_angular*t+angulo_fase)

x = [x*0.01 for x in range(0, 200)]
    
y = [ecua(xt,0) for xt in x]
    
plt.plot(x, y)
plt.show()

# %% [markdown]
# #### c) Perfiles de onda

# %%
def ecua(x,t, af):
    return amplitud*math.sin(n_onda*x+frecuencia_angular*t+af)

af = [0, math.pi/2, math.pi]
x = [x*0.01 for x in range(0, 200)]

for a in af:
    y = [ecua(xt,0,a) for xt in x]
    plt.plot(x, y)   

plt.show()

# %% [markdown]
# # 2. Superposición de ondas

# %% [markdown]
# #### a) Superposición de dos ondas en t=0,00s

# %%
def ecua(x,t, af):
    return amplitud*math.sin(n_onda*x+frecuencia_angular*t+af)

af = [0, math.pi/2, math.pi]
x = [x*0.01 for x in range(0, 200)]

for a in af:
    y = [ecua(xt,0,a) for xt in x]
    plt.plot(x, y)   

plt.show()

# %%
import numpy as np
def ecua(x,t):
    return amplitud*math.sin(n_onda*x+frecuencia_angular*t+af)

n = np.array([1,2,3,4])
long_onda=(2*1.5)/n
print(long_onda)
x = [x*0.01 for x in range(0, 200)]

#for a in af:
    y = [ecua(xt,0) for xt in x]
    plt.plot(x, y)   

plt.show()
# Out:
#   File "<ipython-input-20-5c4d0e69560b>", line 11
#     y = [ecua(xt,0) for xt in x]
#     ^
# IndentationError: unexpected indent
